# %%
import json 
import numpy as np
import pandas as pd

# %%
f = open('no_pii_action_history_v2.json') 

data = json.load(f)
no_pii_action_history_v2=pd.json_normalize(data)
no_pii_action_history_v2
# Out:
#                             _id  \
# 0        MORLY/E/2023/0000001_1
# 1        MORLY/E/2023/0000001_2
# 2        MORLY/E/2023/0000001_3
# 3        MORLY/E/2023/0000001_4
# 4        MORLY/E/2023/0000001_5
# ...                         ...
# 1091341  MODEF/E/2023/0000652_3
# 1091342  MODEF/E/2023/0000652_4
# 1091343  MODEF/E/2023/0000652_1
# 1091344  MODEF/E/2023/0000652_2
# 1091345  MODEF/E/2023/0000652_5
#
#                                              OfficerDetail OfficerDetail_torg  \
# 0                                                     None               None
# 1                                        MAMTA SINGH (DEO)               None
# 2         Anindya Bandyopadhyay (Asstt. Secretary General)               None
# 3             Amit Shyam Roy (Asstt. Commercial Manager 1)               None
# 4             Sri Kartik Singh (Sr. Divisional Engineer 1)               None
# ...                                                    ...                ...
# ...

# %%
f = open('no_pii_grievance_v2.json') 

data = json.load(f)
no_pii_grievance_v2=pd.json_normalize(data)
no_pii_grievance_v2
# Out:
#                          _id UserCode          dist_name org_code pincode  \
# 0       MORLY/E/2023/0000001   110124  North 24 Parganas    MORLY  700130
# 1       GOVUP/E/2023/0000001    45427                NaN    GOVUP  203001
# 2       MOLBR/E/2023/0000001  1356254          Hyderabad    MOLBR  500023
# 3       MOLBR/E/2023/0000002  1092136             Nagpur    MOLBR  440001
# 4       GOVUP/E/2023/0000002    45427                NaN    GOVUP  203001
# ...                      ...      ...                ...      ...     ...
# 175779  UIDAI/E/2023/0001182     None             Pakaur    UIDAI    None
# 175780  DPOST/E/2023/0004221   785742            Cuttack    DPOST  753001
# 175781  MOMAF/E/2023/0000235    14256           Anantnag    MOMAF  192212
# 175782  MOLBR/E/2023/0010864  1722766        Mumbai City    MOLBR  400049
# 175783  MODEF/E/2023/0000652     None          Bhagalpur    MODEF  813209
#
#              registration_no  \
# 0       MORLY/E/2023/0000001
# ...
